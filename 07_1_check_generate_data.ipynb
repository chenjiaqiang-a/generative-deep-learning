# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import world_model.base.config as config
from IPython import display

# %%
file = os.listdir(config.DATA_ROLLOUT_DIR)[60]
print(file)
rollout = np.load(config.DATA_ROLLOUT_DIR + file)
obs_data = rollout['obs']
action_data = rollout['action']
reward_data = rollout['reward']

print(obs_data.shape)
# Out:
# 1051823876.npz
# (300, 64, 64, 3)

# %%
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(64, 64), sharex=True, sharey=True)
plt.subplots_adjust(hspace=0.4)
idx = 40
for x in range(5):
    for y in range(4):
        obs = obs_data[idx]
        axes[x, y].imshow(obs)

        axes[x, y].text(0.5, -0.1, 'frame ' + str(idx), size=40, ha="center",
                        transform=axes[x, y].transAxes)
        axes[x, y].text(0.5, -0.2, 'a = ' + str(np.round(action_data[idx], 2)), size=40, ha="center",
                        transform=axes[x, y].transAxes)
        axes[x, y].text(0.5, -0.3, 'r = ' + str(np.round(reward_data[idx], 2)), size=40, ha="center",
                        transform=axes[x, y].transAxes)

        idx += 1

plt.show()
# Out:
# Text(0.5, -0.1, 'frame 40')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 41')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = 3.35')
# Text(0.5, -0.1, 'frame 42')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 43')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 44')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 45')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = 3.35')
# Text(0.5, -0.1, 'frame 46')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 47')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 48')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 49')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 50')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = 3.35')
# Text(0.5, -0.1, 'frame 51')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 52')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 53')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 54')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = 3.35')
# Text(0.5, -0.1, 'frame 55')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 56')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 57')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
# Text(0.5, -0.1, 'frame 58')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = 3.35')
# Text(0.5, -0.1, 'frame 59')
# Text(0.5, -0.2, 'a = [0. 0. 0.]')
# Text(0.5, -0.3, 'r = -0.1')
